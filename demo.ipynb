# %%
# %load_ext autoreload
# %autoreload 1
import numpy as np
import pandas as pd
import IPython
import plotly.express as px
import plotly.graph_objects as go
# %aimport tccpy

# %%
def show(fig, width=900, height=500,xaxis_title='Target',yaxis_title='Value'):
    fig.update_layout(width=width,height=height,showlegend=False,xaxis_title=xaxis_title,yaxis_title=yaxis_title)
    asImage = True # image plotting is non interactive, but supported in browser. 
    if asImage:
        IPython.display.display(IPython.display.SVG(fig.to_image('svg')))
    else:
        fig.show()

# %% [markdown]
# # Example usage of TCC model
# The following code runs a minimal example usage of the TCC model including four compeating targets with familiarity 0, 0, 1, and 2.

# %%
targets = ['A', 'B', 'C', 'D']
familiarity = pd.DataFrame([0, 0, 1, 2], index=targets)

# %%
dist = tccpy.tcc(familiarity, 100) 
dist
# Out:
#    wins
# A     4
# B     3
# C    17
# D    76

# %%
fig = px.bar(dist)
show(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 fig = px.bar(dist)
# ----> 2 show(fig)
#
# Cell In[9], line 2, in show(fig, width, height, xaxis_label, yaxis_label)
#       1 def show(fig, width=900, height=500,xaxis_label='Target',yaxis_label='Value'):
# ----> 2     fig.update_layout(width=width,height=height,showlegend=False,xaxis_label=xaxis_label,yaxis_label=yaxis_label)
#       3     asImage = True # image plotting is non interactive, but supported in browser.
#       4     if asImage:
#
# File ~/Documents/Source/tccpy/.venv/lib/python3.12/site-packages/plotly/graph_objs/_figure.py:787, in Figure.update_layout(self, dict1, overwrite, **kwargs)
#     761 def update_layout(self, dict1=None, overwrite=False, **kwargs) -> "Figure":
#     762     """
#     763
#     764     Update the properties of the figure's layout with a dict and/or with
# ...

# %% [markdown]
# # Extended example
# The following code runs a slightly larger example including a range of 100 targets, with a bump of familiarity at the center.

# %%
targets2 = np.arange(100)
familiarity2 =  2.0/(1.0+np.exp(np.abs(targets2-50)))

# %%
fig = px.bar(familiarity2)
fig.update_layout(yaxis_title='Familiarity',xaxis_title='Target index')
show(fig)

# %%
dist2 = tccpy.tcc(familiarity2, 10000)
fig = px.bar(dist2)
show(fig)
